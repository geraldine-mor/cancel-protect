# %% [markdown]
# # **Data Collection**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and save as raw data
# * Inspect the data and save to an outputs directory
#
# ## Inputs
#
# * Kaggle JSON file - authentication token required
#
# ## Outputs
#
# * Generate dataset, saved to outputs/datasets/collection/HotelBookings.csv
#
# ## Additional Comments
#
# * ⚠️ -- To be added if required -- ⚠️

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/home/ger/cancel-protect/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))

current_dir = os.getcwd()
current_dir
# Out:
# '/home/ger/cancel-protect'

# %% [markdown]
# ## Setup

# %% [markdown]
# * Install Kaggle (if not already installed)

# %%
# !uv pip install kaggle
# Out:
# Resolved 33 packages in 1.55s
# ⠙ Preparing packages... (0/14)
# ⠙ Preparing packages... (0/14)------------------     0 B/65.10 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/65.10 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.50 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.50 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.50 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdurl                ------------------------------     0 B/9.75 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdurl                ------------------------------     0 B/9.75 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# mdurl                ------------------------------     0 B/9.75 KiB
# mdit-py-plugins      ------------------------------     0 B/65.10 KiB
# text-unidecode       ------------------------------     0 B/76.32 KiB
# tqdm                 ------------------------------     0 B/76.50 KiB
# ⠙ Preparing packages... (0/14)------------------     0 B/76.62 KiB
# python-slugify       ------------------------------ 9.82 KiB/9.82 KiB
# python-dotenv        ------------------------------ 14.81 KiB/21.58 KiB
# fastjsonschema       ------------------------------ 14.77 KiB/23.46 KiB
# mdit-py-plugins      ------------------------------ 14.81 KiB/65.10 KiB
# text-unidecode       ------------------------------ 14.76 KiB/76.32 KiB
# tqdm                 ------------------------------ 14.79 KiB/76.50 KiB
# nbformat             ------------------------------ 14.81 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 14.78 KiB/89.54 KiB
# kaggle               ------------------------------     0 B/132.65 KiB
# bleach               ------------------------------ 16.00 KiB/161.24 KiB
# jupytext             ------------------------------     0 B/166.58 KiB
# kagglesdk            ------------------------------     0 B/225.60 KiB
# ⠙ Preparing packages... (0/14)----------------- 14.81 KiB/788.94 KiB
# python-dotenv        ------------------------------ 14.81 KiB/21.58 KiB
# fastjsonschema       ------------------------------ 14.77 KiB/23.46 KiB
# mdit-py-plugins      ------------------------------ 30.81 KiB/65.10 KiB
# text-unidecode       ------------------------------ 14.76 KiB/76.32 KiB
# tqdm                 ------------------------------ 14.79 KiB/76.50 KiB
# nbformat             ------------------------------ 14.81 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 14.78 KiB/89.54 KiB
# kaggle               ------------------------------ 14.80 KiB/132.65 KiB
# bleach               ------------------------------ 16.00 KiB/161.24 KiB
# jupytext             ------------------------------ 14.84 KiB/166.58 KiB
# kagglesdk            ------------------------------     0 B/225.60 KiB
# ⠙ Preparing packages... (0/14)----------------- 14.81 KiB/788.94 KiB
# python-dotenv        ------------------------------ 14.81 KiB/21.58 KiB
# fastjsonschema       ------------------------------ 14.77 KiB/23.46 KiB
# mdit-py-plugins      ------------------------------ 30.81 KiB/65.10 KiB
# text-unidecode       ------------------------------ 14.76 KiB/76.32 KiB
# tqdm                 ------------------------------ 30.79 KiB/76.50 KiB
# nbformat             ------------------------------ 14.81 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 14.78 KiB/89.54 KiB
# kaggle               ------------------------------ 14.80 KiB/132.65 KiB
# bleach               ------------------------------ 16.00 KiB/161.24 KiB
# jupytext             ------------------------------ 14.84 KiB/166.58 KiB
# kagglesdk            ------------------------------     0 B/225.60 KiB
# ⠙ Preparing packages... (0/14)----------------- 14.81 KiB/788.94 KiB
# fastjsonschema       ------------------------------ 23.46 KiB/23.46 KiB
# mdit-py-plugins      ------------------------------ 30.81 KiB/65.10 KiB
# text-unidecode       ------------------------------ 17.07 KiB/76.32 KiB
# tqdm                 ------------------------------ 30.79 KiB/76.50 KiB
# nbformat             ------------------------------ 30.81 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 14.78 KiB/89.54 KiB
# kaggle               ------------------------------ 14.80 KiB/132.65 KiB
# bleach               ------------------------------ 32.00 KiB/161.24 KiB
# jupytext             ------------------------------ 14.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 16.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)----------------- 14.81 KiB/788.94 KiB
# mdit-py-plugins      ------------------------------ 30.81 KiB/65.10 KiB
# text-unidecode       ------------------------------ 17.07 KiB/76.32 KiB
# tqdm                 ------------------------------ 46.79 KiB/76.50 KiB
# nbformat             ------------------------------ 30.81 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 14.78 KiB/89.54 KiB
# kaggle               ------------------------------ 14.80 KiB/132.65 KiB
# bleach               ------------------------------ 32.00 KiB/161.24 KiB
# jupytext             ------------------------------ 14.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 16.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)----------------- 14.81 KiB/788.94 KiB
# mdit-py-plugins      ------------------------------ 65.10 KiB/65.10 KiB
# text-unidecode       ------------------------------ 49.07 KiB/76.32 KiB
# tqdm                 ------------------------------ 62.79 KiB/76.50 KiB
# nbformat             ------------------------------ 62.81 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 46.68 KiB/89.54 KiB
# kaggle               ------------------------------ 46.80 KiB/132.65 KiB
# bleach               ------------------------------ 60.03 KiB/161.24 KiB
# jupytext             ------------------------------ 46.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 32.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)----------------- 31.22 KiB/788.94 KiB
# text-unidecode       ------------------------------ 49.07 KiB/76.32 KiB
# tqdm                 ------------------------------ 62.79 KiB/76.50 KiB
# nbformat             ------------------------------ 62.81 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 46.68 KiB/89.54 KiB
# kaggle               ------------------------------ 46.80 KiB/132.65 KiB
# bleach               ------------------------------ 60.03 KiB/161.24 KiB
# jupytext             ------------------------------ 46.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 32.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 31.22 KiB/788.94 KiB
# text-unidecode       ------------------------------ 49.07 KiB/76.32 KiB
# nbformat             ------------------------------ 76.62 KiB/76.62 KiB
# markdown-it-py       ------------------------------ 46.68 KiB/89.54 KiB
# kaggle               ------------------------------ 46.80 KiB/132.65 KiB
# bleach               ------------------------------ 60.03 KiB/161.24 KiB
# jupytext             ------------------------------ 46.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 32.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 31.22 KiB/788.94 KiB
# text-unidecode       ------------------------------ 65.07 KiB/76.32 KiB
# markdown-it-py       ------------------------------ 52.71 KiB/89.54 KiB
# kaggle               ------------------------------ 46.80 KiB/132.65 KiB
# bleach               ------------------------------ 60.03 KiB/161.24 KiB
# jupytext             ------------------------------ 46.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 32.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 47.22 KiB/788.94 KiB
# markdown-it-py       ------------------------------ 68.71 KiB/89.54 KiB
# kaggle               ------------------------------ 78.80 KiB/132.65 KiB
# bleach               ------------------------------ 108.03 KiB/161.24 KiB
# jupytext             ------------------------------ 78.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 48.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 78.43 KiB/788.94 KiB
# markdown-it-py       ------------------------------ 78.78 KiB/89.54 KiB
# kaggle               ------------------------------ 126.80 KiB/132.65 KiB
# bleach               ------------------------------ 119.28 KiB/161.24 KiB
# jupytext             ------------------------------ 126.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 68.63 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 110.43 KiB/788.94 KiB
# markdown-it-py       ------------------------------ 78.78 KiB/89.54 KiB
# bleach               ------------------------------ 140.03 KiB/161.24 KiB
# jupytext             ------------------------------ 126.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 80.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 174.43 KiB/788.94 KiB
# bleach               ------------------------------ 140.03 KiB/161.24 KiB
# jupytext             ------------------------------ 126.84 KiB/166.58 KiB
# kagglesdk            ------------------------------ 80.00 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 206.43 KiB/788.94 KiB
# jupytext             ------------------------------ 166.58 KiB/166.58 KiB
# kagglesdk            ------------------------------ 112.37 KiB/225.60 KiB
# ⠙ Preparing packages... (0/14)------------------ 334.43 KiB/788.94 KiB
# kagglesdk            ------------------------------ 112.37 KiB/225.60 KiB
# ⠹ Preparing packages... (11/14)----------------- 334.43 KiB/788.94 KiB
# kagglesdk            ------------------------------ 112.37 KiB/225.60 KiB
# ⠹ Preparing packages... (11/14)m------------ 494.43 KiB/788.94 KiB
# ⠹ Preparing packages... (11/14)m------------ 138.39 KiB/225.60 KiB
# Prepared 14 packages in 260ms
# Installed 15 packages in 489ms
#  + bleach==6.4.0
#  + fastjsonschema==2.21.2
#  + jupytext==1.19.3
#  + kaggle==2.2.2
#  + kagglesdk==0.1.30
#  + markdown-it-py==4.2.0
#  + mdit-py-plugins==0.6.1
#  + mdurl==0.1.2
#  + nbformat==5.10.4
#  + python-dotenv==1.2.2
#  + python-slugify==8.0.4
#  + pyyaml==6.0.3
#  + text-unidecode==1.3
#  + tqdm==4.68.3
#  + webencodings==0.5.1

# %% [markdown]
# * Configure Kaggle
#     * Change the Kaggle directory to the current working directory
#     * Set permissions for the kaggle authentication token

# %%
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
! chmod 600 kaggle.json

# %% [markdown]
# ## Retrieve Dataset

# %% [markdown]
# * Download the dataset .zip file

# %%
! kaggle datasets download -d "jessemostipak/hotel-booking-demand" -p "inputs/datasets"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jessemostipak/hotel-booking-demand
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading hotel-booking-demand.zip to inputs/datasets
# 100%|█████████████████████████████████████| 1.25M/1.25M [00:00<00:00, 2.79MB/s]

# %% [markdown]
# * Unzip the downloaded file, remove the .zip file and credentials file

# %%
! unzip "inputs/datasets"/*.zip -d "inputs/datasets" \
    && rm "inputs/datasets"/*.zip \
    && rm kaggle.json
# Out:
# Archive:  inputs/datasets/hotel-booking-demand.zip
#   inflating: inputs/datasets/hotel_bookings.csv

# %% [markdown]
# ---

# %% [markdown]
# ## Load and Inspect the Dataset

# %%
import pandas as pd
df = pd.read_csv(f"inputs/datasets/hotel_bookings.csv")
df.head()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In case you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create here your folder
  # os.makedirs(name='')
except Exception as e:
  print(e)
